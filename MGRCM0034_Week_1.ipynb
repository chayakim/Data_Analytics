# %% [markdown]
# ![University-of-Bristol-logo-Employer-Champion-profile-2.jpg](data:image/jpeg;base64,...)
#
# #**MGRCM0034: Programming in Business Analytics**
#
# **Week 1: Python Basics (Expressions, Variables, Types and Functions)**

# %% [markdown]
# # **Introduction to Python**
# **What is Python?**
# * Python is one of the most popular programming languages,
# created by Guido van Rossum and released in **1991**.
# * Python is an **interpreted** programming language
#
# **Why python?**
# * Python is a beginner-friendly language due to its simplified syntax which is close to natural
# language.
# * It has been designed to write clear, logical code for small and large-scale projects.
# * It is used extensively in the industry for software development, data science, artificial
# intelligence, and machine learning.

# %% [markdown]
# # **Setting Up Python**
#
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **Jupyter Notebook**
# * Jupyter Notebook is a web application that allows you to create
# documents that may contain code, visualizations, and narrative
# text.
# * It is very popular and is used extensively in data science, artificial
# intelligence, and machine learning.
# * A notebook has the ***.ipynb*** extension.
#
# **Alternatives to Jupyter Notebook**
# * Google Colaboratory is an alternative to Jupyter Notebook and does not require downloading anything.
#
#
#
# > [Google Colaboratory](https://colab.research.google.com/?utm_source=scs-index)

# %% [markdown]
# **What is Colab?**
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more.

# %% [markdown]
# > Now, creat a google account and we can start the coding journey!

# %% [markdown]
# # **Expressions**
# **Arithmetic**
#
# We begin our journey into programming with the concept of *expressions*.
# Have a look at the following example of some Python code, which can help us understand why we say Python is close to natural language.

# %%
10 + 20
# Out:
# 30

# %% [markdown]
# When we *evaluate* `10+20` we get `30`. The expression is `10+20`, the value we get when we evaluate it is `30`.
# This piece of code is called an expression. It has a value which we can evaluate.

# %% [markdown]
# Python supports many arithmetic operations:
# ```Python
# Addition            +
# Subtraction         -
# Multiplication      *
# Power               **
# Division            /
# Floor Division      //
# Modulus             %
# ```

# %% [markdown]
# Your Turn!
#
#
#
# > Try the above arithmetic operations. You can change the code inside below cell, then rerunning the cell!

# %%
'Practice Here'
# Out:
# 1

# %% [markdown]
# **Code Structure**
#
# To be able to write code we need to know how the computer will read it. It is always possible to work out the order in which everything happens.
# When you code Python, you need to know this.
# For example, there is an order of precedence in maths.

# %%
10 + 3 * 2

# %% [markdown]
# The code evaluates to `16`. This is because the computer do `3*2` first, which is `6`, and then add `10`, to ge`t `16.

# %% [markdown]
# Your Turn!
# > If we want to calculate `10+3` first, and then `multipy 2` to get the result of `26`. How to do?

# %%
'Practice Here'
# Out:
# 26

# %%
1 + 2 + 3
1 + 2
# Out:
# 3

# %% [markdown]
# Notice in the cell above that we can run multiple lines of code in succession by writing them one after another.
# But, only the final line result is displayed, the result of `1 + 2` simply 'goes nowhere'.

# %% [markdown]
# **Booleans**
#
# We use numbers a lot in programming, but we use other things too. A Boolean is a value that is either true or false.
# There are many ways you could write these:
# ``` python
# True    False
# T       F
# 1       0
# ```
# In Python, we write `True` and `False` (notice the T and F are upper case).

# %%
True
# Out:
# True

# %%
False

# %% [markdown]
# Notice that both of the cells above each just contain a single Boolean value, but we could still consider them expressions.

# %% [markdown]
# Boolean Operations:
# ```
# * AND
# * OR
# * NOT
# ```
# Here is how they work:
# ```
#   X AND Y      is true if X and Y are both true, otherwise the result is false
#   X OR Y       is true if either X or Y are true, otherwise the result is false
#   NOT X        flips the value of X: true becomes false, false becomes true
# ```
# In Python, we use `and`, `or` and `not`.

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# There is also one precedence order for Boolean operator, it goes:
#
# 1.   `not`
# 2.   `and`
# 3.   `or`

# %%
not False and not False or False
# Out:
# True

# %% [markdown]
# Can you see why?
#
# **NOT** is applied first:
# ```python
#   (not False) and (not False) or False
# ```
# then **AND**:
# ```python
#   # (True and True) or False
#   ((not False) and (not False)) or False
# ```
# finally **OR**:
# ```python
#   # (True or False
#   (((not False) and (not False)) or False)
# ```

# %% [markdown]
# Your Turn!
# > Try some combinations and think why.

# %%
'Practice Here'

# %% [markdown]
# # **Variables**

# %% [markdown]
# **Example**
#
# FA is a farm who sells free range eggs. The farm feeds total 10,000 hens. Currently, each hen lays one egg every two days.The farm uses size-100 box to package eggs for customers. The farm owner purchases boxes each week and the price of each box is 2 pounds.
# Can you calculate how much the farm owner will use to buy the boxes each week?

# %%
10000 / 2 / 100 * 7 * 2
# Out:
# 700.0

# %% [markdown]
# The answer I got is 700 pounds.
#
# But,
# if we write this down somewhere and come back to it later will we have any idea what is going on?
# And if we want to change some values (for example: the hen lays one egg per day, box price increases), how to do?

# %% [markdown]
# **Variables**
#
# Thankfully, we can make this situation much better using *variables*. A variable is a named value. You can create variables with almost any name you like, set their values, change them, and use them in other expressions.
# Variables are an essential part of programming, they:
# * Make code easier to read
# * Make code easier to change

# %% [markdown]
# To create a new variable in Python called `box_size` with a value equal to `100`, we write:
# ```python
#     box_size = 100
# ```
# This is called **assignment**, and is an example of a statement. Statements, unlike expressions, do not produce a resulting value.

# %%
box_size = 100

# %% [markdown]
# If we want to output the result of box_size, we need:

# %%
box_size = 100
box_size
# Out:
# 10

# %% [markdown]
# ***Assignments***
#
# The left hand side of an assignment is a variable name. The right hand side is any expression.
# So the statement
# ```python
#     box_size = 100
# ```
# assigns the value `100` to the name box_size. If we use box_size in a later expression, it will act as if we had written the value `100`

# %%
box_size = 100
box_size * 7
# Out:
# 700

# %% [markdown]
# A better version with variables

# %%
hen_num = 10000
hen_lay_freq = 2
box_size = 100
box_buy_freq = 7
price_per_box = 2

eggs_per_day = hen_num / hen_lay_freq
box_demand_per_day = eggs_per_day / box_size
box_num_per_purchase = box_demand_per_day * box_buy_freq
cost_per_order = box_num_per_purchase * price_per_box
# cost_per_order = hen_num / hen_lay_freq / box_size * box_buy_freq * price_per_box

cost_per_order
# Out:
# 700.0

# %% [markdown]
# The final line of this cell display the value of the variable `cost_per_order` in the output of the cell
# -- it is an expression containing just the variable `cost_per_order`.
#
# This code is a lot longer than the version we had before! At first glance it might look more confusing.
# But, if you read it carefully, and read the variable names, you should be able to follow what is going on.
#
# Now it is incredibly easy to change the calculation. Perhaps we want to try using large box, feed more hens,
# increase the box purchasing frequence. These changes are easy to make by changing the first few lines,
# and we can re-run the cell to instantly re-use the same logic.

# %% [markdown]
# ***Readability and Comments***
#
# The variable names do not matter to Python, they are just for human readers. You might be tempted to just use any placeholder,
# like a or x for our variables. In fact, most programmers will do this from time to time.
# But using descriptive names makes the code much easier to read, so you should always try to use human-readable variables names.
#
# We can make the code even easier to read by adding ***comments***. Anything written after a hash symbol `#` will be ignored by Python.
#
# We normally write comments on the line above the line they refer to, rather than on the same line as other code,
# this makes it easier for people who use screen readers to read the comments.

# %%
# number of hens in the farm
hen_num = 10000
# the frequency of each hen to lay egg (days)
hen_lay_freq = 2
# the size of box
box_size = 100
# box purchasing frequency (days)
box_buy_freq = 7
# price of each box (pound)
price_per_box = 2

# caculate the number of boxes each purchasing
eggs_per_day = hen_num / hen_lay_freq
box_demand_per_day = eggs_per_day / box_size
box_num_per_purchase = box_demand_per_day * box_buy_freq
cost_per_order = box_num_per_purchase * price_per_box

# output the total cost of each order
cost_per_order
# Out:
# 700.0

# %% [markdown]
# Use comments thoughtfully. If you expect someone else to read your code, then you should use comments to guide them. Even if you do not expect anyone else to read your code, you might want to write comments for a future version of you!
# It is easy to forget what we were trying to do in code we wrote months or years ago. Used well, comments can guide you through tricky code, and save you lots of time trying to figure out what something does, and why.
#
# However, the goal is readable code, not lots of comments. Over-commenting will also make code harder to read, so you certainly do not need to comment every line of code.

# %% [markdown]
# Your Turn!
# > I'm evaluating food options for a dog. The guidelines on the side of his current bag of food say that for a dog of his age, he should eat 100g of food per day per 10kg body weight. Since he is 70kg, that means he should eat 700g of food per day. Sadly, he has been showing some signs of food allergies, so I would like to try him on another source of protein. I know for certain that he is not allergic to eggs. Of course, this would not be a balanced diet, but how many eggs would he need to eat per day to meet his daily calorie requirement? Note: do not feed a dog only eggs! Talk to your vet about nutritional requirements. I know that his current food provides 3600kcal/kg. A medium egg is about 60kcal. So how many eggs a day would he need to eat?
# > Coulf you work this out by using variables?

# %%
'Practice Here'

# %% [markdown]
# # **Types**

# %% [markdown]
# **Numbers**
#
# Data within Python always has a specific ***type***, and it's really important to be able to keep track of and predict what type a certain
# value or variable will be, because the type of a value can change how it works in certain circumstances.
#
# We can find the ***type*** of a particular value in Python using the following syntax: `type(x)`.

# %%
type(100)
# Out:
# int

# %% [markdown]
# `type(100)` gives `int` --> `100` is a type of number called an ***integer***

# %%
type(True)
# Out:
# bool

# %% [markdown]
# `type(x)` is called a ***function***. Any expression written in the place of `x` will first be evaluated, then the type of the result will be outputted as the result of the overall expression.

# %%
type(1 + 2 + 3)
# Out:
# int

# %% [markdown]
# Your Turn!
# > Try some expressions and find their types

# %%
'Practice Here'

# %% [markdown]
# **Variables**
#
# Python is a dynamically typed language.
#
# Cells here run in one big environment, so if we make a variable in one cell we can modify and use it in another cell,
# as you can see from the examples below.
# ```python
#     num = 10
# ```

# %%
num = 10
type(num)
# Out:
# int

# %%
type(num + 2.0)
# Out:
# float

# %%
num = num / 2
type(num)
# Out:
# float

# %% [markdown]
# float is short for ***floating point***. This is the format that computers use to store fractional (decimal) numbers.
# We know that `10 ÷ 2` results in an integer, but in Python, the result is always a float. Python will indicate this by writing 5.0 instead of 5.

# %%
10 / 2
# Out:
# 5.0

# %% [markdown]
# **Some Operators**
#
# However, we do occasionally want to have control over the type of our data.
# Suppose we are doing division where we want the answer to be an integer.
# There are a few options for this.

# %%
200 / 3
# Out:
# 66.66666666666667

# %%
# We can use // instead of /
200 // 3
# Out:
# 66

# %%
# used the function called int(x) to convert the number into an integer
int (200 / 3)
# Out:
# 66

# %%
# used the function called round(x) to convert the number into an integer
round (200 / 3)
# Out:
# 67

# %% [markdown]
# ***Combining Types***
#
# There are some very common operations that combine types, where the output is not be the same type as the input

# %%
type(10 > 2)
# Out:
# bool

# %% [markdown]
# Type is useful for understanding what sort of operations make sense. We can do
# ```python
#   10 + 20
# ```
# and
# ```python
#   True and True
# ```
# but
# ```python
#   True + True
# ```
# doesn't really make sense. The addition operation `+` is defined for two numbers and the result is a number.
# The AND operation `and` is defined for two Booleans and the result is a Boolean. It doesn't really make sense to add two Boolean values.

# %% [markdown]
# **Strings**
#
# We use text a lot in programming too, and we have a special name for this data type; it is called a ***string***.
# Strings in Python are written with a pair of quote symbols. You can use `"` or `'`, so long as you use the same one at the beginning
# and end of the string. Python is clever enough to let you use single quotes inside a string terminated with double quotes, or vice versa.
# Here are some valid Python strings:
# ```python
#   "This is a string"
#   'This is also a string'
#   "Isn't it a string?"
# ```
# We can perform some operations on strings too. If we add two strings then they are concatenated:

# %%
"string one" + "string two"
# Out:
# 'string onestring two'

# %% [markdown]
# Notice that this operation is literal: it won't insert a space for you if you don't ask for one!

# %%
# We can also multiply a string by a number to repeat a string many times
'Repeat important thing three times! ' *3
# Out:
# 'Repeat important thing three times! Repeat important thing three times! Repeat important thing three times! '

# %% [markdown]
# We can index a string using square brackets` [` and `]`. It is common in computer science to start counting sequences from zero, not one. So the first character of a string is element zero, the second character is element one, and so on.

# %%
'Bristol'[0]
# Out:
# 'B'

# %%
'Bristol'[2]
# Out:
# 'i'

# %% [markdown]
# Your Turn!
# > Try modifying the code in these cells and rerunning them.
# Try different values, try another string, guess what the result will be before you hit run.

# %%
'Practice Here'

# %% [markdown]
# We know there are 7 charaters in 'Bristol'

# %%
len('Bristol')
# Out:
# 7

# %% [markdown]
# > Guess what the result will be  if the index is too large?

# %%
'Bristol'[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-44751febd924> in <cell line: 1>()
# ----> 1 'Bristol'[10]
#
# IndexError: string index out of range

# %% [markdown]
# If we want to get the last charater of the string.

# %%
'Bristol'[len('Bristol')-1]
# Out:
# 'l'

# %%
text = 'Bristol'
text[len(text)-1]
# Out:
# 'l'

# %%
text[-1]
# Out:
# 'l'

# %%
text[-2]
# Out:
# 'o'

# %% [markdown]
# But be careful: if you go beyond the length of the string in either direction you will get an error!

# %% [markdown]
# You can access a range of indices from a string (also called a substring). If text is a string variable, then writing
# ```python
#   text[x:y]
# ```
# will give you the substring from position x up to but not including position y.
# In the example below, notice how `text[2:4]` returns the characters with indices 2 and 3 (but not 4) from the string:

# %%
text = 'Bristol'
text[2:4]
# Out:
# 'is'

# %% [markdown]
# You can leave out `x` or` y` entirely to get a substring that goes all the way from the beginning or to the end of the string, respectively.

# %%
text[2:]
# Out:
# 'istol'

# %%
text[:4]
# Out:
# 'Bris'

# %% [markdown]
# **Numbers in Strings**

# %%
10 + 0.5

# %%
"string number" + "string number"

# %%
"string number:" + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-b77e34f7742b> in <cell line: 1>()
# ----> 1 "string one" + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
"string number:" + str(10)

# %%
'10' + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4ac0513be2aa> in <cell line: 1>()
# ----> 1 '10' + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
'10' + '10'
# Out:
# '1010'

# %%
10 + 10

# %% [markdown]
# Now you can see why it's so important that you understand the types of your data, even if Python handles it all for you when it comes to assigning types to variables.

# %% [markdown]
# We often want to insert numbers into strings when you write code. Suppose we want to get something like this:
# ```
#   'this is attempt 3 of 5, your current score is 80 out of 100.'
# ```

# %%
"this is attempt " + str(3) + " of " + str(5) + ", your current score is " + str(80) + " out of " + str(100) + "."
# Out:
# 'this is attempt 3 of 5, your current score is 80 out of 100.'

# %%
f"this is attempt {3} of {5}, your current score is {80} out of {100}"
# Out:
# 'this is attempt 5 of 10, your current score is 30 out of 100'

# %% [markdown]
# Notice the `f` right before the start of the string. When we place that `f` before the string, anything written between `{` and `} `will be evaluated. So you can insert variables or even arithmetic here too. This is what our code is more likely to look like in practice.

# %%
attempt = 3
max_attempts = 5
score = 80
max_score = 100

f"this is attempt {attempt} of {max_attempts}, your current score is {score} out of {max_score}"

# %% [markdown]
# # **Functions**
#
# Some definitions:
# * Function – named block of code
# * Calling (a function) – when we run a function from somewhere else in the code
# * Parameters – the inputs to a function from its point of view (e.g. a function with two parameters)
# * Arguments – the actual data passed into a function when we call it
# * Return value – the output of a function
#
# The syntax for calling a function with three parameters is:
# ```python
# function_name(arg_1, arg_2, arg_3)
# ```
#
# We saw functions like `type`, `len`, and `round` in previous notebooks. They are inbuild functions.
#
# **Inbuilt Functions**

# %%
round (10.6)
# Out:
# 9

# %% [markdown]
# In this example
#
#   ```python
#   round(10.6)
#   ```
#
# the function is round, the argument is 10.6, and the return value is 10.
#
# Here is another example:

# %%
pow(2,3)
# Out:
# 8

# %% [markdown]
# The name is `pow`, and when the arguments are `2` and `3` the return value is `8`.
#
# Can you work out what it does from the name and the values shown?
#
# Remember you can always try changing the values and rerunning the cell! Try that before moving on.
#
# `pow(x, y)` calculates `x` to the power of `y`. Or written mathematically: $x^y$.
#
# We can also write this in Python using the `**` **operator**:

# %%
2 ** 3

# %% [markdown]
# The difference between these two forms is *basically* just syntax. We call `**` an operator, and `pow` a function, but they both take two numbers as inputs and they both return a single number.
#
# You saw many other arithmetic and Boolean operators in last session, such as addition `+` or NOT `not`. You can think of all operators as being a special syntax for common functions.
#
# We can mix and match operators and functions to create big expressions:

# %%
(len('Bristol') + round(20 / 3)) ** 2
# Out:
# 196

# %% [markdown]
# We said earlier that functions *may* return values. Technically, a **function** is a special type of **subroutine**. All **functions** return values. But some **subroutines** do not return values, and these are called **procedures**.
# Here is one example, it is called `help`:

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# When we use the `help` procedure, we get some information about whatever *object* we pass in. This information is not *returned*, it is simply displayed on the screen. So `help` really is a procedure.
#
# You cannot assign `help(len)` to a variable.

# %% [markdown]
# Your Turn!
#
# > Here are three more inbuilt functions you might find useful in future: `max(x, y)`, `min(x, y)`, and `abs(x)`. They all take numbers as arguments. Experiment with the cell below to see if you can work out what each one does, even if you think it is obvious from the names. You could try some example arguments, or use the help procedure.

# %%
# try using the functions max(x, y), min(x, y), and abs(x) here!
# examples: max(3, 5), min(-1, 10), abs(-10)
'Practice Here'

# %% [markdown]
# There are also many inbuild string functions. Here we can have a look at one example called `find`. It allows us to find a character (or substring) inside a string, and tells us the index that it occurs. So if we wanted to find the character `"i"` in the string `"Bristol"` the find function will return `2`. *(Remember that string indices start at 0.)*
#
# This function only works for strings. So rather than having a function that works like this
# ```python
# find('Bristol', 'i')
# ```
# the function *belongs* to the string object, and is used like this:
# ```python
# 'Bristol'.find('i')
# ```

# %%
'Bristol'.find('i')
# Out:
# 2

# %%
'Bristol'.find('ist')
# Out:
# 2

# %%
# If the substring is not found, then the return value is -1.
'Bristol'.find('k')
# Out:
# -1

# %%
# Another example
'Bristol'.replace('B','b')
# Out:
# 'bristol'

# %%
text = 'Bristol'
text.replace('B','b')
text
# Out:
# 'Bristol'

# %% [markdown]
# The output of the above cell is still the original string. The `B` is not changed into the `b`, why?
#
# The reason is because `replace` ***returns*** a value. It does not *change* the string. It is an *expression*, not a *statement*. It is a *function*, not a *procedure*.
#
# To actually update the variable with the new value, we must **capture** the return value by *assigning* it again:

# %%
text = 'Bristol'
text = text.replace('B','b')
text
# Out:
# 'bristol'

# %% [markdown]
# Your Turn!
#
# > Strings have lots of useful functions like this. Do not feel like you have to learn them all now. You can read the list that is available in the [Python documentation](https://docs.python.org/3/library/stdtypes.html#string-methods).
#
# > Try some of them.

# %%
'Practice Here'

# %% [markdown]
# **Custom Functions**

# %% [markdown]
# We have already learnt inbuild functions, and we showed you how we could write our own version of the `pow` function that looks like this:
#
# ```python
# def pow(x, y):
#     return x ** y
# ```
#
# For the benefit of easy reference, let's repeat the breakdown of each component. The first line is called the **signature**:
# ```python
# def pow(x, y):
# ```
# * `def`
# * This keyword indicates this is a *function definition*
# * `pow`
# * The name of the function, this is what we will *call* later
# * `(x, y)`
# * We list all of the *parameters* (inputs) of the function and give them variable names – we can call them whatever we like
# * `:`
# * This colon indicates the start of a new *block* of code
# * At least one but possibly more of the following lines of code will *belong* to this function
#
# Now let's add the second line:
# ```python
# def pow(x, y):
#     return x ** y
# ```
# * `⇥`
# * Notice this line is *indented* – there are four spaces (or a *tab* character) at the start of this line
# * If a line ends in a colon `:` then the next line ***must*** be indented
# * Every indented line is considered part of the same block of code – in this case, part of the same function
# * `return`
# * This keyword indicates that we are ending the function and the result of evaluating the expression on the right hand side will be *returned* (outputted)
# * `x ** y`
# * Finally, this is the calculation that the function will do with the input parameters `x` and `y`
#
# Here is a demonstration of this function in action that you can run and play around with. I have renamed the function to `my_pow` so we can demonstrate it is not just the same as the builtin function `pow`:

# %%
def my_pow(x, y):
    return x ** y

my_pow(2, 5)
# Out:
# 32

# %% [markdown]
# ***More Examples***
#
# Here are some more examples of custom functions. This first one takes a number of minutes and a number of seconds and returns the total number of seconds:

# %%
def total_seconds(minutes, seconds):
    return minutes*60 + seconds

total_seconds(10, 20)
# Out:
# 620

# %% [markdown]
# This next function is a bit more complicated. Notice two things
# 1. We can have multiple lines of code inside a function so long as they are all indented. We can even assign variables and use them.
# 2. The syntax `""" ... """` can be used for a multi-line comment. It is common to comment more complicated functions like this with a multi-line comment directly after the *signature*:

# %%
def age(birthday, countday):
    """ Calculates the number of years between two dates, rounding up
        Only works for modern dates!

        Assumes dates are input as strings in the format
            dd/MM/yyyy
        e.g. 1st December 2019 is "01/12/2019"
    """
    year1 = int(birthday[6:])
    year2 = int(countday[6:])
    return abs(year1 - year2)

age("30/12/1993","01/05/2016")
# Out:
# 23

# %% [markdown]
# ***Scope***
#
# Now that we are using variables inside functions we need to talk about **scope**. When you create a new variable inside a function it only exists *inside* that function. Outside of the function it will be like the variable never existed.
#
# Pay careful attention to the following code examples:

# %%
def add(x, y):
    z = x + y
    return z

add(10, 10)
# Out:
# 20

# %% [markdown]
# If we query the value of `z` after running the function `add`, we will get an error:

# %%
def add(x, y):
    z = x + y
    return z

add(10, 10)
z

# %% [markdown]
# Below shows a very similar example but with the variable called `elephant` instead of `z`. This time, the variable has a value before the function is defined. Notice that *neither* defining nor calling the function changes the value of `elephant` when we query it at the end.

# %%
elephant = 100

def add(x, y):
    elephant = x + y
    return elephant

add(10, 10)
elephant
# Out:
# 100

# %%
elephant = 100

def add(x, y):
    result = x + y + elephant
    return result

add(10, 10)
# Out:
# 120

# %%
elephant = 100

def add(x, y, elephant):
    result = x + y + elephant
    return result

add(10, 10, elephant)
# Out:
# 120

# %% [markdown]
# Your Turn!
#
# > Build a function which can swap the first and last characters of the string 'Bristol'.

# %%
'Practice Here'

# %% [markdown]
# ***Functions of Functions***
#
# Functions are named blocks of code. You can write any code in a function, including calls to other functions

# %%
def function_one(x):
    if x > 0:
        return function_two(x)
    else:
        return x * 2

def function_two(x):
    if x < 0:
        return function_one(x)
    else:
        return x * 3

function_one(3)
